# %% [markdown]
# ## Download GSV Pano and depth map for Launceston using streetlevel python library
# * streetlevel is a library for downloading panoramas and metadata from street-level imagery services such as Google Street View, Apple Look Around, and several others. To install the package use: _pip install streetlevel_

# %% [markdown]
# * This notebook is basically same with the notebook to download GSV data for Wagga, but slightly different in a few parameters due to the difference in attribute fields in the ground-truth building points.

# %% [markdown]
# ## Load modules

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from streetlevel import streetview
import geopandas as gpd
import json
import os
import re
from PIL import Image
from glob import glob
from aiohttp import ClientSession
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Set input and output folders
# * A vector of building points
# * Output folders for Panorama images and depth maps

# %%
add_points=r'C:\Users\lliu\FrontierSI\Projects - 127 Residential Dwelling Floor Height\4 Executing\GA_data_documentation\Launceston Exposure Data\LC_Final\LC_Final.shp'
output_folder_pano=r'D:\Launceston\GSV\Pano'
output_folder_depth=r'D:\Launceston\GSV\Depth'
# output_folder_pano=r'C:\Users\lliu\Desktop\FrontierSI\projects\GA_floor_height\GA-floor-height\output\Wagga\Panos\streetlevel'
# output_folder_depth=r'C:\Users\lliu\Desktop\FrontierSI\projects\GA_floor_height\GA-floor-height\output\Wagga\Depth_decoded\streetlevel'

# %% [markdown]
# ## Load GNAF points

# %%
gdf_points=gpd.read_file(add_points).to_crs('epsg:4326')
gdf_points.head()
# Out:
#          EASTING      NORTHING   UFI                    ZONE       DEM  \
# 0  510962.988188  5.412541e+06  1002    15.0 Urban Mixed Use  2.697813
# 1  511021.688427  5.412248e+06    33  11.0 Inner Residential  4.208417
# 2  511082.136711  5.412226e+06    31  11.0 Inner Residential  4.540370
# 3  511068.760790  5.412219e+06    28  11.0 Inner Residential  5.212643
# 4  511048.726805  5.412229e+06    26  11.0 Inner Residential  5.162260
#
#                    LID              ADDRESS      SUBURB POSTCODE FEATURE_NA  \
# 0  GNAF_GATAS702308914       13 PARK STREET  LAUNCESTON     7250       None
# 1  GNAF_GATAS702204375  293 BRISBANE STREET  LAUNCESTON     7250       None
# 2  GNAF_GATAS702478623      4 MIDDLE STREET  LAUNCESTON     7250       None
# 3  GNAF_GATAS702296648      6 MIDDLE STREET  LAUNCESTON     7250       None
# 4  GNAF_GATAS702290011      8 MIDDLE STREET  LAUNCESTON     7250       None
#
#    ... Min_OBJECT  LCC_FLOOR  check1   POINT_X_1  POINT_Y_1  ROWS  \
# 0  ...     1061.0       3.12     0.0  147.131228 -41.438625   1.0
# 1  ...        0.0       3.33     0.0  147.131936 -41.441268   1.0
# 2  ...        0.0       3.70     0.0  147.132660 -41.441464   1.0
# 3  ...        0.0       3.37     0.0  147.132500 -41.441522   1.0
# 4  ...        0.0       3.37     0.0  147.132260 -41.441433   1.0
#
#            SA11 GVULN GVULV                     geometry
# 0  6.020110e+10   4.0  10.0  POINT (147.13123 -41.43862)
# 1  6.020110e+10   4.0  10.0  POINT (147.13194 -41.44127)
# 2  6.020110e+10   4.0  10.0  POINT (147.13266 -41.44146)
# 3  6.020110e+10   4.0  10.0  POINT (147.13250 -41.44152)
# 4  6.020110e+10   4.0  10.0  POINT (147.13226 -41.44143)
#
# [5 rows x 67 columns]

# %% [markdown]
# ### View points

# %%
gdf_points.explore(column='LCC_FLOOR')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_33b0d628a23ac2cd2807fd77caa7b13c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_33b0d628a23ac2cd2807fd77caa7b13c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_33b0d628a23ac2cd2807fd77caa7b13c = L.map(
#                 &quot;map_33b0d628a23ac2cd2807fd77caa7b13c&quot;,
#                 {
#                     center: [-41.42589949999999, 147.13587549999997],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_33b0d628a23ac2cd2807fd77caa7b13c);
#
#
#
#
#
#             var tile_layer_a90099bf5e425f179fb215b23049b155 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a90099bf5e425f179fb215b23049b155.addTo(map_33b0d628a23ac2cd2807fd77caa7b13c);
#
#
#             map_33b0d628a23ac2cd2807fd77caa7b13c.fitBounds(
#                 [[-41.442821, 147.11449099999996], [-41.40897799999998, 147.15725999999998]],
#                 {}
#             );
#
#
#         function geo_json_cf580aaa20eb7062ea9f253443fa0b1c_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;443&quot;: case &quot;852&quot;:
#                     return {&quot;color&quot;: &quot;#26818e&quot;, &quot;fillColor&quot;: &quot;#26818e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;5&quot;: case &quot;1141&quot;: case &quot;1216&quot;: case &quot;1218&quot;:
#                     return {&quot;color&quot;: &quot;#24878e&quot;, &quot;fillColor&quot;: &quot;#24878e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;137&quot;: case &quot;141&quot;: case &quot;168&quot;: case &quot;169&quot;: case &quot;194&quot;: case &quot;196&quot;: case &quot;321&quot;: case &quot;451&quot;: case &quot;801&quot;: case &quot;811&quot;: case &quot;812&quot;: case &quot;1232&quot;:
#                     return {&quot;color&quot;: &quot;#20938c&quot;, &quot;fillColor&quot;: &quot;#20938c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;4&quot;: case &quot;294&quot;: case &quot;462&quot;: case &quot;1110&quot;: case &quot;1111&quot;: case &quot;1134&quot;: case &quot;1135&quot;: case &quot;1150&quot;: case &quot;1258&quot;:
#                     return {&quot;color&quot;: &quot;#23898e&quot;, &quot;fillColor&quot;: &quot;#23898e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;18&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;117&quot;: case &quot;269&quot;: case &quot;334&quot;: case &quot;336&quot;: case &quot;354&quot;: case &quot;488&quot;: case &quot;544&quot;: case &quot;550&quot;: case &quot;573&quot;: case &quot;645&quot;: case &quot;648&quot;: case &quot;669&quot;: case &quot;671&quot;: case &quot;672&quot;: case &quot;673&quot;: case &quot;883&quot;: case &quot;1023&quot;: case &quot;1028&quot;: case &quot;1029&quot;: case &quot;1031&quot;: case &quot;1045&quot;: case &quot;1049&quot;:
#                     return {&quot;color&quot;: &quot;#3c508b&quot;, &quot;fillColor&quot;: &quot;#3c508b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;57&quot;: case &quot;252&quot;: case &quot;267&quot;: case &quot;504&quot;: case &quot;537&quot;: case &quot;540&quot;: case &quot;882&quot;: case &quot;967&quot;: case &quot;974&quot;:
#                     return {&quot;color&quot;: &quot;#404588&quot;, &quot;fillColor&quot;: &quot;#404588&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;: case &quot;10&quot;: case &quot;59&quot;: case &quot;85&quot;: case &quot;229&quot;: case &quot;233&quot;: case &quot;514&quot;: case &quot;542&quot;: case &quot;593&quot;: case &quot;625&quot;: case &quot;685&quot;: case &quot;972&quot;: case &quot;979&quot;: case &quot;981&quot;: case &quot;1036&quot;: case &quot;1037&quot;: case &quot;1054&quot;:
#                     return {&quot;color&quot;: &quot;#3e4c8a&quot;, &quot;fillColor&quot;: &quot;#3e4c8a&quot;, &quot;fillOpacity&quo

# %%
gdf_points['Floor_height']=gdf_points['LCC_FLOOR']

# %% [markdown]
# ## Test workflow with first point
# ### Get point coordinates

# %%
i=0
lon=gdf_points.geometry.iloc[i].x
lat=gdf_points.geometry.iloc[i].y

# %% [markdown]
# ### Record ground-truth FFH

# %%
ffh_gt=gdf_points.iloc[i]['Floor_height']
ffh_gt
# Out:
# 3.12

# %% [markdown]
# ### Search and download panorama without depth

# %%
zoom=5
pano = streetview.find_panorama(lat, lon)
pano
# Out:
# YNLZF16ubLTqrzW7SkVC3A (-41.43855, 147.13145) [2019-10]

# %%
pano.elevation
# Out:
# 5.546634674072266

# %%
if pano is None:
    print('cannot find pano for location',lat,lon)
else:
    out_file_pano=os.path.join(output_folder_pano,pano.id+'.jpg')
    if os.path.exists(out_file_pano):
        print('pano file exists, skipping...')
    else:
        print('downloading to file ',out_file_pano)
        async with ClientSession() as session:
            await streetview.download_panorama_async(pano,out_file_pano,session,zoom=zoom)
# Out:
# downloading to file  D:\Launceston\GSV\Pano\YNLZF16ubLTqrzW7SkVC3A.jpg

# %% [markdown]
# ### Download depth map using pano id

# %%
pano_with_depth = streetview.find_panorama_by_id(pano.id,download_depth=True)
depth_arr=pano_with_depth.depth.data
depth_img = Image.fromarray(depth_arr)
# plt.imshow(depth_arr)

# %%
depth_arr.shape
# Out:
# (256, 512)

# %% [markdown]
# Allow large image to be loaded:

# %%
Image.MAX_IMAGE_PIXELS=None

# %% [markdown]
# ### Upscale depth map to the same dimension as pano (optional)

# %%
# if os.path.exists(out_file_pano):
#     with Image.open(out_file_pano) as img:
#         pano_size=img.size
# resampled_depth = depth_img.resize(pano_size, resample=Image.BILINEAR)

# %% [markdown]
# ### Save depth map

# %%
out_file_depth=os.path.join(output_folder_depth,pano.id+'.tif')
if os.path.exists(out_file_depth):
    print('pano file exists, skipping...')
else:
    # resampled_depth.save(out_file, format='TIFF',compression='tiff_deflate')
    depth_img.save(out_file_depth, format='TIFF',compression='tiff_deflate')

# %% [markdown]
# ## Batch querying pano metadata

# %%
gdf_points_meta=gdf_points.copy()
gdf_points_meta['pano_id']=pd.NA
gdf_points_meta['lat_c']=pd.NA
gdf_points_meta['lng_c']=pd.NA
gdf_points_meta['heading']=pd.NA
gdf_points_meta['pitch']=pd.NA
gdf_points_meta['roll']=pd.NA
gdf_points_meta['elevation']=pd.NA
gdf_points_meta['date']=pd.NA

# %%
for i in range(len(gdf_points)):
    lon=gdf_points.geometry.iloc[i].x
    lat=gdf_points.geometry.iloc[i].y
    pano = streetview.find_panorama(lat, lon)
    if not pano is None:
        gdf_points_meta.at[i,'pano_id']=pano.id
        gdf_points_meta.at[i,'lat_c']=pano.lat
        gdf_points_meta.at[i,'lng_c']=pano.lon
        gdf_points_meta.at[i,'heading']=pano.heading
        gdf_points_meta.at[i,'pitch']=pano.pitch
        gdf_points_meta.at[i,'roll']=pano.roll
        gdf_points_meta.at[i,'elevation']=pano.elevation
        gdf_points_meta.at[i,'date']=pano.date
    else:
        print('cannot find pano for location',lat,lon)
gdf_points_meta
# Out:
# cannot find pano for location -41.42497799999999 147.12215799999998
# cannot find pano for location -41.426159874099994 147.12372464999999
# cannot find pano for location -41.424454999999995 147.12429099999997
# cannot find pano for location -41.424494999999986 147.12318399999998
# cannot find pano for location -41.42407099999999 147.12577799999997
# cannot find pano for location -41.429205 147.125652
# cannot find pano for location -41.42757799999999 147.12440799999996
# cannot find pano for location -41.41658899999999 147.13120299999997
# cannot find pano for location -41.417378 147.13116099999996
# cannot find pano for location -41.41726299999998 147.14194699999996
# cannot find pano for location -41.41844499999999 147.14206599999997
# cannot find pano for location -41.410308999999984 147.13431899999998
# cannot find pano for location -41.429657999999996 147.14524299999997
# cannot find pano for location -41.42748299999999 147.15009899999998
# cannot find pano for location -41.42756899999999 147.15038699999997
# cannot find pano for location -41.427632 147.150792
# cannot find pano for location -41.43185899999999 147.15410099999997
# cannot find pano for location -41.431986 147.15461299999998
# cannot find pano for location -41.432309 147.15449299999997
# cannot find pano for location -41.43218199999999 147.15376399999997
# cannot find pano for location -41.432049 147.15350599999996
# cannot find pano for location -41.429789 147.15403799999999
# cannot find pano for location -41.41106200000001 147.13331399999998
# cannot find pano for location -41.41097799999999 147.133194
# cannot find pano for location -41.42611999999999 147.15725999999998
#             EASTING      NORTHING   UFI                    ZONE       DEM  \
# 0     510962.988188  5.412541e+06  1002    15.0 Urban Mixed Use  2.697813
# 1     511021.688427  5.412248e+06    33  11.0 Inner Residential  4.208417
# 2     511082.136711  5.412226e+06    31  11.0 Inner Residential  4.540370
# 3     511068.760790  5.412219e+06    28  11.0 Inner Residential  5.212643
# 4     511048.726805  5.412229e+06    26  11.0 Inner Residential  5.162260
# ...             ...           ...   ...                     ...       ...
# 1271  511678.913227  5.415060e+06  1415         23.0 Commercial  2.530000
# 1272  511662.145037  5.415079e+06  1416         23.0 Commercial  2.383714
# 1273  511635.268231  5.415099e+06  1417         23.0 Commercial  2.317272
# 1274  511690.687378  5.415003e+06   870         23.0 Commercial  3.437857
# 1275  511709.605447  5.415022e+06   874         23.0 Commercial  2.550646
#
#                       LID              ADDRESS      SUBURB POSTCODE  \
# 0     GNAF_GATAS702308914       13 PARK STREET  LAUNCESTON     7250
# 1     GNAF_GATAS702204375  293 BRISBANE STREET  LAUNCESTON     7250
# 2     GNAF_GATAS702478623      4 MIDDLE STREET  LAUNCESTON     7250
# 3     GNAF_GATAS702296648      6 MIDDLE STREET  LAUNCESTON     7250
# 4     GNAF_GATAS702290011      8 MIDDLE STREET  LAUNCESTON     7250
# ...                   ...                  ...         ...      ...
# 1271  GNAF_GATAS716623620     26 OSWALD STREET    INVERMAY     7248
# 1272  GNAF_GATAS702465036     28 OSWALD STREET    INVERMAY     7248
# 1273  GNAF_GATAS702317895     32 OSWALD STREET    INVERMAY     7248
# 1274  GNAF_GATAS702219883      40 BURNS STREET    INVERMAY     7248
# 1275  GNAF_GATAS702219879      42 BURNS STREET    INVERMAY     7248
#
#      FEATURE_NA  ...                     geometry  Floor_height  \
# 0          None  ...  POINT (147.13123 -41.43862)          3.12
# 1          None  ...  POINT (147.13194 -41.44127)          3.33
# 2          None  ...  POINT (147.13266 -41.44146)          3.70
# 3          None  ...  POINT (147.13250 -41.44152)          3.37
# 4          None  ...  POINT (147.13226 -41.44143)          3.37
# ...         ...  ...                          ...           ...
# 1271       None  ...  POINT (147.13975 -41.41592)          2.61
# 1272       None  ...  POINT (147.13955 -41.41576)          2.61
# 1273       None  ...  POINT (147.13923 -41.41557)          2.48
# 1274       None  ...  POINT (147.13989 -41.41644)          4.12
# 1275       None  ...  POINT (147.14012 -41.41627)          3.47
#
#                      pano_id      lat_c       lng_c   heading     pitch  \
# 0     YNLZF16ubLTqrzW7SkVC3A -41.438551  147.131445  5.841477  0.022252
# 1     Tz6NjkiBNSG1ge0lKjXhdg -41.441052  147.131782  1.040822  0.037883
# 2     hANXkavpLZzicH-g505L6g -41.441531  147.132669  0.957574  0.039241
# 3     kC4sWh0ZUf1E7nz52Fb9xA -41.441585  147.132567  0.963067  0.051902
# 4     hw9Rgp7d5H3mb-WlVW-Z_A -41.441662  147.132419  0.959565  0.034847
# ...                      ...        ...         ...       ...       ...
# 1271  zlExcFoRXIFgqEMdWbk8Jw -41.416136  147.139393  2.542899 -0.008668
# 1272  q57A-gkokKQu757cn3CV0A -41.415947  147.139221   2.54142 -0.025394
# 1273  TgdWgi_3bubHkVsiWDj7RQ -41.415716  147.139029  2.563032  -0.02469
# 1274  CsBIbz8-ybkm1cCmVFIIVA -41.416494  147.139735  2.471215 -0.021353
# 1275  MkFvuKC93rQKzD5H1ffb2g -41.416405  147.140269  4.084902 -0.015375
#
#           roll elevation     date
# 0     6.228637  5.546635  2019-10
# 1     6.235322  5.922997  2023-09
# 2     0.022607   7.15661  2023-09
# 3     0.010492  7.739836  2023-09
# 4     0.021449  8.384348  2023-09
# ...        ...       ...      ...
# 1271  0.015574   6.60992  2023-09
# 1272  6.271691  6.408826  2023-09
# 1273  6.264193  5.787523  2023-09
# 1274  6.247352  7.106176  2023-09
# 1275  6.264801  6.946608  2023-09
#
# [1276 rows x 76 columns]

# %% [markdown]
# ## Save the metadata

# %%
gdf_points_meta['date'] = gdf_points_meta['date'].astype('string')
gdf_points_meta['heading'] = gdf_points_meta['heading'].replace(pd.NA, np.nan).astype('float')
gdf_points_meta['lat_c'] = gdf_points_meta['lat_c'].replace(pd.NA, np.nan).astype('float')
gdf_points_meta['lng_c'] = gdf_points_meta['lng_c'].replace(pd.NA, np.nan).astype('float')
gdf_points_meta['pitch'] = gdf_points_meta['pitch'].replace(pd.NA, np.nan).astype('float')
gdf_points_meta['roll'] = gdf_points_meta['roll'].replace(pd.NA, np.nan).astype('float')
gdf_points_meta['elevation'] = gdf_points_meta['elevation'].replace(pd.NA, np.nan).astype('float')
# Out:
# C:\Users\lliu\AppData\Local\Temp\ipykernel_16320\3730501706.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf_points_meta['heading'] = gdf_points_meta['heading'].replace(pd.NA, np.nan).astype('float')
# C:\Users\lliu\AppData\Local\Temp\ipykernel_16320\3730501706.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf_points_meta['lat_c'] = gdf_points_meta['lat_c'].replace(pd.NA, np.nan).astype('float')
# C:\Users\lliu\AppData\Local\Temp\ipykernel_16320\3730501706.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf_points_meta['lng_c'] = gdf_points_meta['lng_c'].replace(pd.NA, np.nan).astype('float')
# C:\Users\lliu\AppData\Local\Temp\ipykernel_16320\3730501706.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf_points_meta['pitch'] = gdf_points_meta['pitch'].replace(pd.NA, np.nan).astype('float')
# C:\Users\lliu\AppData\Local\Temp\ipykernel_16320\3730501706.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf_points_meta['roll'] = gdf_points_meta['roll'].replace(pd.NA, np.nan).astype('float')
# C:\Users\lliu\AppData\Local\Temp\ipykernel_16320\3730501706.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gdf_points_meta['elevation'] = gdf_points_meta['elevation'].replace(pd.NA, np.nan).astype('float')

# %%
outfile_meta='D:\Launceston\GSV\LC_Final_meta.geojson'
gdf_points_meta.to_file(outfile_meta, driver="GeoJSON")
# to avoid overwriting
# if not os.path.exists(outfile_meta):
#     gdf_points_meta.to_file(outfile_meta, driver="GeoJSON")

# %% [markdown]
# ## Batch downloading

# %%
pano_ids=gdf_points_meta['pano_id'][gdf_points_meta['pano_id'].notna()]
len(pano_ids)
# Out:
# 1251

# %%
for pano_id in pano_ids:
    out_file_pano=os.path.join(output_folder_pano,pano_id+'.jpg')
    if os.path.exists(out_file_pano):
        print('pano file exists, skipping...')
    else:
        pano=streetview.find_panorama_by_id(pano_id,download_depth=False)
        if pano is None:
            print('cannot find pano')
        else:
            try:
                print('downloading to file ',out_file_pano)
                async with ClientSession() as session:
                    await streetview.download_panorama_async(pano,out_file_pano,session,zoom=zoom)
            except Exception as e:
                print(e)

    out_file_depth=os.path.join(output_folder_depth,pano_id+'.tif')
    if os.path.exists(out_file_depth):
        print('depth map exists, skipping...')
    else:
        try:
            pano_with_depth = streetview.find_panorama_by_id(pano_id,download_depth=True)
            if pano_with_depth is None:
                print('cannot decode depth map pano ',pano_id)
            else:
                print('decoding depth map')
                depth_arr=pano_with_depth.depth.data
                depth_img = Image.fromarray(depth_arr)
                # resampled_depth.save(out_file, format='TIFF',compression='tiff_deflate')
                depth_img.save(out_file_depth, format='TIFF',compression='tiff_deflate')
        except Exception as e:
            print(e)
# Out:
# pano file exists, skipping...
# depth map exists, skipping...
# downloading to file  D:\Launceston\GSV\Pano\Tz6NjkiBNSG1ge0lKjXhdg.jpg
# decoding depth map
# downloading to file  D:\Launceston\GSV\Pano\hANXkavpLZzicH-g505L6g.jpg
# decoding depth map
# downloading to file  D:\Launceston\GSV\Pano\kC4sWh0ZUf1E7nz52Fb9xA.jpg
# decoding depth map
# downloading to file  D:\Launceston\GSV\Pano\hw9Rgp7d5H3mb-WlVW-Z_A.jpg
# decoding depth map
# downloading to file  D:\Launceston\GSV\Pano\OH5vAtnkf1rJ0PBWned9Gw.jpg
# decoding depth map
# downloading to file  D:\Launceston\GSV\Pano\GvP_WNzTHiz53PaBhohUcw.jpg
# decoding depth map
# downloading to file  D:\Launceston\GSV\Pano\yUC9VsjcbhJLP9IhkcS9NA.jpg
# decoding depth map
# downloading to file  D:\Launceston\GSV\Pano\1dWomAWXYA5WBVKOUSsupg.jpg
# decoding depth map
# downloading to file  D:\Launceston\GSV\Pano\04NHb7NoIVI3bCJWr7dqxA.jpg
# decoding depth map
# downloading to file  D:\Launceston\GSV\Pano\ofzSLVU6ziUOhvOKVoIdlA.jpg
# decoding depth map
# downloading to file  D:\Launceston\GSV\Pano\GCqm-qp3lXYJeZI-5zO6Xw.jpg
# decoding depth map
# downloading to file  D:\Launceston\GSV\Pano\sCRba75bznE7O7pOkz8ERw.jpg
# decoding depth map
# downloading to file  D:\Launceston\GSV\Pano\-7-8do-k_kmU_TkKERDq3Q.jpg
# decoding depth map
# downloading to file  D:\Launceston\GSV\Pano\xS1tTvpge2h0H2HQrge99Q.jpg
# decoding depth map
# downloading to file  D:\Launceston\GSV\Pano\Ml-Y4hdpstAED8QqaWBR9w.jpg
# decoding depth map
# downloading to file  D:\Launceston\GSV\Pano\1U8qnCO8CLG0PbCI3LuxNA.jpg
# decoding depth map
# downloading to file  D:\Launceston\GSV\Pano\PuXd4_vLjxhc3D9FrfD5Ow.jpg
# decoding depth map
# pano file exists, skipping...
# depth map exists, skipping...
# downloading to file  D:\Launceston\GSV\Pano\FEmH8xfEwN_pC3jQp6HTXQ.jpg
# decoding depth map
# pano file exists, skipping...
# depth map exists, skipping...
# downloading to file  D:\Launceston\GSV\Pano